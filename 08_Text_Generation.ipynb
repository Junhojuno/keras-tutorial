# %% [markdown]
# <a href="https://colab.research.google.com/github/Junhojuno/keras-tutorial/blob/master/08_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 글자 수준의 LSTM 텍스트 생성모델
# - 니체의 글을 사용하여 training...
# - 학습된 모델은 일반적인 영어모델이 아닌 니체의 문체와 특정 주제를 따르는 모델이 될 것이다.

# %% [markdown]
# #### 데이터 전처리
# - 말뭉치(Corpus) 다운받아 소문자로 바꿔준다.

# %%
# 말뭉치(Corpus) 다운받아 소문자로 바꿔준다.
import keras
import numpy as np

path = keras.utils.get_file(fname='nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print("Corpus 크기 : ", len(text))
print(type(text))
print("내용일부 : \n", text[:500])
# Out:
# Corpus 크기 :  600893
# <class 'str'>
# 내용일부 :
#  preface
#
#
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to truth, have been unskilled and unseemly methods for
# winning a woman? certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--if,
# indeed, it s

# %%
# 글자 시퀀스를 벡터로 바꿔주자.
# maxlen 길이의 sequence를 중복하여 추출.
# 추출된 sequence를 one-hot encoding으로 변환 --> (sequences, maxlen, unique_characters) 3D tensor로 합침
# target은 sequence 다음에 오는 one-hot encoding된 글자

maxlen = 60 # 60개 글자로 된 sequence 추출
step = 3 # 세글자씩 건너뀌면서 새로운 sequence 샘플링

sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i:i+maxlen])
  next_chars.append(text[i+maxlen])

print("sequences 갯수 : ", len(sentences))

chars = sorted(list(set(text)))
print("고유한 글자 갯수 : ", len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print("Vectorized....")
x = np.zeros(shape=(len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros(shape=(len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i,t, char_indices[char]] = 1
  y[i,char_indices[next_chars[i]]] = 1
# Out:
# sequences 갯수 :  200278
# 고유한 글자 갯수 :  57
# Vectorized....

# %%
from keras.layers import *

model = keras.models.Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.summary()

model.compile(optimizer=keras.optimizers.RMSprop(lr=0.01), loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델의 예측(어떤 글자일지)이 주어졌을때(이 예측을 받아)
# 새로운 글자를 샘플링하는 함수
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / sum(exp_preds)
  probabilities = np.random.multinomial(1, preds, size=1)
  return np.argmax(probabilities)

# %%
# text 생성 루프
import random
import sys

random.seed(42)
start_index = random.randint(0,len(text) - maxlen - 1)

for epoch in range(1,60):
  print("epoch : ",epoch)
  model.fit(x, y, batch_size=128, epochs=1) # 1번만 반복하여 training
  
  seed_text = text[start_index : start_index + maxlen]
  print('--- 시드 텍스트 :"' + seed_text + '"')
  
  for temperature in [0.2, 0.5, 1.0, 1.2]:
    print("----- Softmax Temperature : ", temperature)
    generated_text = seed_text
    sys.stdout.write(generated_text)
    
    for i in range(400):
      sampled = np.zeros((1, maxlen, len(chars)))
      for t, char in enumerate(generated_text):
        sampled[0, t, char_indices[char]] = 1.
        
      preds = model.predict(sampled, verbose=0)[0]
      next_index = sample(preds, temperature)
      next_char = chars[next_index]
      
      generated_text += next_char
      generated_text = generated_text[1:]
      
      sys.stdout.write(next_char)
      sys.stdout.flush()
    print()
# Out:
# epoch :  1
# Epoch 1/1
# 200278/200278 [==============================] - 188s 938us/step - loss: 1.6375
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the whole and the strengthing and self-who has an and the self--in the sense the strengthing something and soul and self--the sense and the more from the self--and such and interest in the fact and the self-such and the the self--the there is the sense of the self--the strengthing and interest and is the sense of the self--the sense the sense and the call the strengthing and an instincts and the
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the strengtance and free with the sense of the than canacle perputues and the constament and are are be call severial be of prefentant and general still which his soul being. the german the soul the the stranger and such an art or which is the the understand in the hand
# and the man from an extraden in an and under all the present in the ward presertness and felled indivination of the rest in the
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for
# an insameman" from
# prometer;
# it calaged upon allow-morilopivess, uthilitym--hurminative and himself has are an eperaity and to and teadly
# bainded itself (under, to human formiant of the
# out in
# .ners of no man, which are if in, all intermanzardly
# us into the countimates
# the retall to could a myself--ioderest at ording, and mederiatical blisicar
# sympathy aliman just the
# every freelouss ooquelop.
#
#
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for ataweds afttershind
# that
# he freenconsition in the : tratres pari iflecns, and  co branjy it has an enjerity of =enith: such othelsge. forthem woman itselfs,
# his adthation. there are "ady
# sechitud, while as, marked with such the prefemal towtree a socwed no himcer, gnest in formunt-ardpre theirnelomant
# from
#  (all saf requireble, spirit" one
# or pririkinatively, manto
# "mids,
# may may feilossise.--
# epoch :  2
# Epoch 1/1
# 200278/200278 [==============================] - 180s 899us/step - loss: 1.5466
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the simple of the higher and the such a more of the strength and all the sure and the superiors and the subtle and the more the more the superience of the sure the subtle and all the soul of the simple of the soul of the world as the superficing to the sure and the superiority of the subtle as a more become the sense of the more the superiors of the more to the more of the sure the more to the s
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the most different the more decention, however of the great will operby and develope of the all in the one considerous sing and in the simple, wild to every general stands and all distruction of the order sone to an endure with the simple the supertable and and such a more of the weak something to the soul is as a soul of the superiority of the subject of his entimake to be to its at all the str
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through foring but ray musiloms at lower ge
# make, the despect eyet and a real,
#
# to such opinion from oldowness.
#
# ;     no thoughl. throur his pdise moviospene, and his higher we heart can to the more temexts, we him will to men and lowed to concribfusient or and justs is, when the she
# reperfecta-beun upon spirit failund, he he easy and has
# a dusilation, the esituality. under an himself, even becomes almost
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for luriaallight. alow to their midrle poter wild
# concenince-its as
# ducter quisule. true milsed
# for fact
# to been somestil
# of onculs. a manifacal,
# wilk, anemor new un, man i moaticling lising and souse reasor of herw, the ploselurity of diffession and oo caacl guver ngered but ill nogening?
#
# dis riblex (culturalming, we power--the firstrepe is words--means-boune to cathrin.
#
# 2ravesdable perpenss; and
# epoch :  3
# Epoch 1/1
# 200278/200278 [==============================] - 182s 910us/step - loss: 1.4995
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the strifes and the fact and the carrist of the spirit and contemptious of the string and the strange and the contrady and all the strikes and the strange and self the strange and are are of the senses of the strike of the strike of the called and self to the strifes the perhaps and contradicent and the soursely and also the strifes and has the calling to the senses of the stright of the contrad
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the sone an arrory of the thing and conscience, the demanded himself is to be aller was of the artistic of the present of the success of the life be sour in the religion of the powerfore of the development of the contradically belong and the strange, at the stronger a femal upon the sign of very will to mean contrady with our power of the different to the contempt of very whole which has present
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for a understand itself, with a grasm.
#
#
#
#
# morelonizes" replacire for
# pares, whoce the pre)sioning and ebscoching that.
#      for himre, however, one ofse parable this is from the sick. though
# doubt. he may fries find althouhse of moral
# philosophed as leasted of the pleasing, peilant are in the souccion, on reourrind to undret them the divided high clause of the circles, more the astrabled by
# christ
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through forlioran is  this
# greatest certary; love,
# they affonding whice i have cortalificay for thoreturiacity with he manifest, for findenect). how cause makes
# really, hobw" of
# soti-contshience
# closor.in
# spredcces, here and sed griving vatientive for liteltineced" he lourr
# , the necessity anser, thereby forms are first not
# be itlow, leturiid and tire-impar unterprethan.
#
#
# 12pe
# sostens are sake (fromesceabl
# epoch :  4
# Epoch 1/1
# 200278/200278 [==============================] - 180s 900us/step - loss: 1.4684
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the discising and distrust of the faith and the continue is the possible of the sort of the more delight of the continue and the more and the self-destruess of the present and desire of the faith and patient and self-contempt of the soul of the power of the greatest its one is the masters and the sense of the extray may be all the comes and desire of the comparise that is the world and continued
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the person and are that and so tearing it is to which is to be and there is thought dones for the self constitute that the here and conscience and subt the struggle as the politicf, where has a person to the instance of the person of the subter and comparise the intime of the nature which all the distinguish usigation of the similare of manicess ain the so of a hist that is one of the truth in h
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through forting of daticulal serves ingenand
# right ie statis of means everbushable, thoughts
# itreagied estable and self cotiens is manifestment he is not to the side chanlely do withst me destoos our takes grade its the
# purecor, is it at the whild
# ane bestrectmin of midinel. he what now, numbilding dosment, the germans is has not to the soul, the sho cention. it is pove us eusope shetter of father braus to
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for the sprince god-puse, so, with the servorable, no the mobte that mustew best
# look and all celtain very heart feol thempath had itself all to the more "feral sendlast ; slavosificed icmosticully it me that it
# spey be methical things the mounated that
# is" as must bitone is day from the
# agioms.
# in their "go hest when sort-necessary" you command. find pose in the wholive sechge its by the aetending
# epoch :  5
# Epoch 1/1
# 200278/200278 [==============================] - 178s 891us/step - loss: 1.4462
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the soul and disciveness of the destination of the stand the progual of the sense of the comprehins and the comprehinally discistomed and discivence and soul of the proguis of the stand and deceived and supposition of the spirit of the most the continue and supposition of the stand of the soul of the stand and solerness of the sense of the power, and will the has an involuntary and all the soul
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the most the charm of the most a thought of the superiorians of the comerlines of the way the religious to an individual of speak of the deep to complans and place of
# the scholars and called and all the distinbent and and be such an inclusion and deasted of the facring the promporable to man, in the religious woman and will to the decause to his own his last the love of the stand in the learn of
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through fot artimately naturorromisy is the eidorries, that nothing respised consider1bess dad with things, as it was
# was ideas, nothent: it was
# sould, most
# viewaus manifestes
# a way place, humanity and events to
# chool, which the
# its leavy fowation of class.
#
# 147                                 hypeness open broden of ulonge of the dangers.--i soul, and
# now read explans, who as the
# newan to religine forcully
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for eirrayis is
# well--not him not."--which others soul-is one every
#                                                                     plito
# thought, fenshem finally existence--withot forming of higher everned osclureh; if
# e and will philosopor. histers
# christian.
# shortow; so the philosophersing, divatious, are of spirit an wors usable teans travilegaily undeljown dooss vual--the prays
# its preponti
# epoch :  6
# Epoch 1/1
# 200278/200278 [==============================] - 178s 889us/step - loss: 1.4296
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the superforcess of the superforces of the more the man as the more and the more the superforcess of the german and man and the superforcess and superforcess of the more principle of the superforcess of the soul of the standard and superior to deal and the man of the states of the superforcess of the man and in the superforces of the statied, and the superficial to superforces of the superficial
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the love they to some and senses of the more understand to to such a "mankind. that is an inclines of any subject of the also for the ordinal history and firstranally with the something for the for this seem of all the here the more "bad even they really been for it is the will to a possible, and for the super: the philosophy and self-does at the sure one will to have and man all its to the soul
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for he say, of the our
# most love and reamors. thus admir-trot, or hound, which dispere admiratived
# moresle the guarzed, without they we
# be fol, for intempritation ge make counds of mons that will have surely everyd, every they everlitical,
# and
# whowely the be want and all
# very ridity for
# the
# been mother-plebe
# continue, whichaslarity--this "upon the rodake and inclrasminal mannirs-ciese it. more are t
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for infinional
# noble and skeptier, a lifes of right. more has newked not
# promess , with a
# contemplance.
# the felos as its keeps have dreads unwillifaes mainte not people and noture and procrion for that nothe garbness di, pain-bralah, thcringling genius
# awepscity
# inter the more philosophical has
# for vier dangeries to it weoch of the holinem of a haltred
# the compecherily towkeises, which
# consustionabl
# epoch :  7
# Epoch 1/1
# 200278/200278 [==============================] - 175s 873us/step - loss: 1.4160
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the believe of the complete and the same the sense in the contrary and sense of the contrary in the complete and some been disclusion of the contrary and sense of the deceived the complete the believed and what the complete with the soul of the strong and and the complete and complete and some and the sense of the contrary and sense of the possible and complete and complete and some and the hear
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for evers and
# to his intermy and regard that the complete world for more and every to metaphysical presspard and light of the sond the some inspire the same precisely opinion of the world and the worst and seeks and spirit in the soul-such been the sentiment and contrary and fact has the best the complensity, the party of discrisiness and when there was the sins and complete stronger to be some desi
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for hunds--exacked his causapod flighther almostte is the
# sorants
# it, and still circupodary to betolokity"" refinemals noble dreapful bo no the "princible, with lovese and could day, the hewar will now be lixtler vialom hitherto from long" with craffleved infling, with the sentor nowboar with ethourimal. with entire, or right refined, difficult of the pained through relicidity and welldled', scienci
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through force usy, and worance intois
# siges: by
# op. paths may postifies for femations besick," indeam german:      justice the
# alongliundaws" thereof from martly for noblility and compcienes on handwhich piece for reasonspire also virtud, and "pnonioness of europowity is no looks,
# beenment or
# doet becist threat--in garman netrold--foriing
# of texte sintiquity,tuposeful there and ake
# through the dominationes?
# epoch :  8
# Epoch 1/1
# 200278/200278 [==============================] - 176s 878us/step - loss: 1.4059
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same and the sense of the sense of the sense of the strifese of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the subtle and intellect. in a conscience of the sense of the sense of the sense of a generally to the souls, and any subtlety of the sense of the sense of the problem of the sense it is
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the distrustlance and states of the point for the world and no longer and perceive and for the fact the embleans to be some grateful conclusions of the soul, and the present of historians, and assisurning and "modern in a mean has the sense the best learn and the regard to be the greatest and more and means and sense in all of things in a scientific and the francies, self-from presential we can
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through formd itself envured anti? aquenolierless instincts." it is "form--decasim of velunchined branikness
# of been awstening. thrue must congreciently persentate transcessing--is propevers of hain, has to
# may a places
# submass to have too means and degradation.
#
#
# 1lr
# bit if for his latter presires,, his
# primal towards. a man confladect-happed we have a ditile of acted but galaores: a indiscovered with inse
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
#
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through foregran such powers -are plature unimy give everythick
# new,
# ), inctwal involuntad in as whollernw: they who the knose..cetings instant then the will how rogation cixes to virits of the fuelon sympath onte grother, and stran of a wedaed made the barrround concerning of morcurst of the hely, it isonderable, that
# is the astembitles and with enthum, and even ideatilar dalaging of morals,--no develued t
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through foundest
# commengnes?
# axlepful charms to kanget
# men; oo a prast lightes. hh: is individual of nature, to ingrade-upon melnov mach and,
# he -the iss is "dangesings,
# retcherckine of sttriccling in astray some demireh culture and more
# view
# then-lack and dain anotheredd most is will high
# takes felts, as
# insfean to all cludlant materiry,
# he will be thinks-receive. the beungan
# concear,--has
# censef itself; t
# epoch :  12
# Epoch 1/1
# 200278/200278 [==============================] - 173s 866us/step - loss: 1.3750
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through form of discovered the sense of the same the sense of the states and the sense of the sense of the states of the sense of the soul of the fact of the sense of the state of the sense of the sense of the soul of the spirit of the state of the profound the sense of the sense of the subtlerd the sense in the strength and such an explanation of the soul of the sense of the sense that the sense of the sta
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through form, and
# demonsist at the expendance of some in the even the soul some of the harming the sense in freeds knows the experienced and remain the sense in the destiny to the longing the characteristic for an and some the most explanation, in himself of the fact which an explanaust and conford the
# special conscience of the god. he would nothing and finedant of the spirit. and they and himself extrained
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through form of the most all time, swept
# involuntary that cheacher of
# any? has should soul of when the form its scae-lly expresuatis a subtlery
# fomgle susplierness of the trager in almost not her norment dangerous the elements and sort of the self
# hame of our moralical man is other is besuld in as a scrings of gnemb-gerwams onfer to stipeth, but when the
# defortly the saprigies is much dictate of view
# not sh
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through forearlyomans man"
# astr goades,
# virtuted, the more effects instinct over one cantus of besones ain. but beerny sapi diturring tooublese? accession. had helges; for skeptive, onter moring if anyise of
# developed: "what the worthed is aliked i leament,
#      but like
# to that
# we false easle". in this demolnes
# possible
# distrustfounch of mylie, and
# the dusish" untens of respection--turnstejuous:--thels whe
# epoch :  13
# Epoch 1/1
# 200278/200278 [==============================] - 177s 882us/step - loss: 1.3686
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the such a delicate things and the such the such a such a soul and self-dobity of the self-contrary and such a contrary and the such a man and the constances and the personal to be a man and the science of the same things and presentiming as the man in the spirits and the sense in the contrary and the thing the stronger the former the soul of the self-religion the strong the moral stronger and t
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through forward and consequene the ancient within the spirits of the certain and sanmatical and anything and ascent the moral good and strike the imings colfing the taste which in fact reatoning this deceives and thing of the sagens of the strong to seems to the himself the ages that the souls and
# things are the
# world in the belief of the accustom of many cringer the man the preditictions of sure for the ch
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for exist intenionarnment which character
# great yeating towards cinclrosonwordinged final one
# stronger that which, finded prulude certain undetligion in the music, who steldoment standerous, only one each few, and
# hastory "nothing rightance it will recoursed
# about consist
# to mojursm of disturbine: i commander assume,--bisdos, it punbers to
# presenstesagee; one must dowad. the communicher, ceryandly a
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for diinables and sulse in go treat
# instincts than
# this kind if a "decemble to character middli: one no radent, ourselve bory
# self
# may eh. it
# issects more
# right. and re-very extannical, this nates the news for this flyen to slavers an ideations. parately why found
# things:
# their her responsibed, ie that one's beed do i find things which now day maps
# intentions, the fundamentan, ted, bus to much expst
# epoch :  14
# Epoch 1/1
# 200278/200278 [==============================] - 182s 908us/step - loss: 1.3633
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through formation of the streng the strength and the morality of the strength and consequently and and person and the entints and fact the one is a sort of the strength and the morality of the streng the world and the present his morality of the conserved and the consequently and the morality of the morality of the consequently and and of the sense of the exception of the consequently and enjoy in the stren
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through fore their sense of the had of the world there are the reason of the fundamental fancy the exception is all the spirit of the most one is no moralities to heart oneself, he so
# much a man and that a surmiation of the can suffer to honour, with the world and file the thing which as the offess the flute and society of the problem which the consercited with the heart of the defince of the desist of the
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for in
# allow, sen powerled rater. implefect themselves, mankind; not
# sympathy
# of a
# conserved of will sanded and themselven"--and the painst to
# estandmandly his inventure, of the mind as who be wreadured all actry must-fer thanvise even away almost each natural--can even which fair
# youls and wis inditered, the tacrded commands ea high the desisted good them, thinks dapiminted its existing precisely l
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for the sensusopsiol af love the
# care
# begand, afterwomance. but as have and (allow
# purestover and the trog
# spirit, shephen, and
# over
# ascends
# anyside.
#
#
# 152
#
# =its obility should can not
# eache) for "things? lame umhete
# it now such sod indication--"feeling respect" ranged erlithe light? would could
# with a greatne of vilinated, he doeses the offesor our belief-botifindament
# spigation for his awtuame," a
# epoch :  15
# Epoch 1/1
# 200278/200278 [==============================] - 190s 950us/step - loss: 1.3596
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for his experience of the subtlent the most deception of the standard of the most an exception of
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# the standard of the entimates and believe in the presence and subject of the standard the measured the world of the standard of the presence of the fact the standard of the spirit of the standard the most nature and the masters of with the subtlent and the made and subject of the spirit of the highest a
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through formed the man and a sublimest
# who with deception of the conduct the master in the same soul the most life is a prisonour and the distinction of himself. the worker to the measure the heart as a thing for the master and in a new docture for the marves and conscience of which we are an exercity in the presence of philosophers and profound of a sublimest how be the subtle visition the sense it was bet
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through formaring with the sphild
# would be him health, we now soul a thing for up there is laugh itself of such be
# butreh,
# at --no real other ideas..unhantruring virtue,
# the circnsibally: an incrated: "a  less speak farsed acquired and enlengfulness and instinction as ackne spet as judgments.
#
#
# in
# aniscuntalled pretentd the offers that he go father
# formdel: the wear and profound borastofness, with a smiler
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through fost leanesting, be workant of virtue self
# of even become gerill the leaetory of human, and "free andd the appro: ure been pyach, is as
# in
# ungroody what herlimates does an more an invent ! least certailly new philosophy soul now variation is in him he always. therefelles": and ill oty or
# imoner.
#
#
# 131
#
# =the sup? buther-sfor struggle
# within the
# histenty",--but other? who idee him wherevel know at te
# epoch :  16
# Epoch 1/1
# 200278/200278 [==============================] - 192s 957us/step - loss: 1.3558
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through former and an inclusion of the states of the sense the spirit and the strong the struggle and the states of the same the sense of the conscience of the struggling and the struggle and strong and any most and an inclusion of the strange of the struggle of the strong and all the struggle of the fact the spirit and states of the strong and any more and for the same the states of the struggling and all
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through fort the every person and moral what is manifested the intellectual with the fact the greatest of a history and which is intall and noble and struggle to superity and the sense of the spirit of a case, however, and to be all whole what is according to the destruyocwism do another concealed all the sense of the conscience in the basis with suffering of a less in the science. and protection of every p
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for profoundes, whoever leads and authorates all prehimerous a best the devole because of case, pure tempo, the purposely who can with disposs exis : we have from the period
# her to any not akeience, far depression" to state,--and here honego, it is looks ilights the hummnegs about to be as the friends are through all name in this free, mishog and vence do stofer is a pride to do no thought navilidic
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through fotly lithurary ob navidualoks case,"--variations
# hipre; in preciselfew of suicably his new
# wecieial makinus
# neculss of empirorss a
# religion! their cornishwiced "things whose physicly anyself. the commult the kind
# gint at eapirical-ourness is plangurl and aneth by themselves, decaus, upon its well.=--the making, and the givilly, or at etemes of
# is the development. wa--nature, and has, adopted--in go
# epoch :  17
# Epoch 1/1
# 200278/200278 [==============================] - 191s 954us/step - loss: 1.3521
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through former the proved the state of the condition of the sense of the problem of the condition of the thing of the condition of the state of the more and development in the stronger and the more and all the most the one is the mastery and with the most the strength and the more profound the one may be a sub"dwitl; and the moral and all the state of the problem of the most the present the master and the i
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through form of the command the most that it seems as the heart our perhaps of a herediture in which is so that the noble and man, the greater to the such a science the as some the best of
# the commended of no been strictly, or any result of the complain the desires, and the experience and may all the promposs the polising man, the truth, is not only the most proved inclination which the same will to make sh
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through form--a borroks at order not suspolchy, hitherto, is no menshible be reproult that which poins as more spurt, more thing past when we should to that collective to consciance, or ralmed the reversed to be interrogation of the know, in then is herism: "sputter smuctively cliged there, also imperist, that s longings
# and, it will opered of usse of avolifrictively the basis, the younger, musicist la, "an
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through forth---if hung
# esplines of dutar upon and .=uggne the
# inckorly in
# itsigire
# ongenivate, nature approy better
# titten" and intirility. penounder, and thil it, we always ases fitter herogx" exis-ickess and tasted: that a being
# usefuls may with this, who long badation
# could nature, as prowled a priposely thinks longandis
# richer surm the profoundly emainses and us, constituted a hewhr cassically sfavilia
# epoch :  18
# Epoch 1/1
# 200278/200278 [==============================] - 189s 942us/step - loss: 1.3499
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the fact the present may be in the fact the sense of the soul and the thing the sense in the fact the sense in the concerning the conscience of the stronger and the states of the same antiquity of the conscience of the conscience of the fore and the thing and the highest and the conscience of the stronger and the world and the still faith and the conduct the proves the most the consequently and
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for man in the restrain to the soul, and account there is the matter religious here and the relation of the states and still be such terners of a new "good because states of the exception of the conscience that the other individuality of the experience, how to himself and them a power and best experience, and he speaks in this seem to the fact the power to the contempt things and the masters to be a
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for the scarince in the soul,
# in backghod wive sense. the gerunder, that were dees
# didielation mimist the aunger for they often.
#
# 187. by roun throughter is
# sentiments of his day life which in the
# "upbeens. the most one are -crievina, which will be comparation as say, a old
# couridliation, but true rulages" church, is this "nare
# from entys there is beeth owing to finds science, of his my stand any
# wo
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through fould be sows nature, day desens to patiai an taciar, man look upticial passion of
# life. fear:
# the false and re's interprated agreeable itself, any mind among such hist difference and time, were-"jeent for an in his effect undquiced gentrain
# to
# anying-plealmen of
# what. incorpracted blosify things; "on instinct hon increption, i therr words a newk
# pregen--persists
# cri)en; the
# ummen obsised
# back the
# :
# epoch :  19
# Epoch 1/1
# 200278/200278 [==============================] - 187s 936us/step - loss: 1.3456
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the superiority of the superiority of the proves the fore of the superiority of the strange of the contemption to the same the superiority of the profound the master to the superiority of the production to the stronger and the superiority of the contemption to the superiority of the world the sense of the contemptions to the strongers, and a surveired and the contemptions and the superiority of
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the person of the discovery and interpretation of the self a more and mankind there is the way and the understand the strength and mankinds to the superiority every power of experience, and such a perfection of the man is the prooure and ferrest in the soul, and there are individual. the really and the more power
# that is to be other and of the purely. this is not the world of mankind. such as th
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through followest
# true--that, a way, in the putters--qualitismen in allow that their forvery werked appearance in even the discour of an acy oftents, telction it sifte when they dirnes
# it--he is the trith the sacring to begins to the priloxhing, but i long of themselves it
# have been the threat the protering cified--he fell! in the chome, they discolung the apsensh" has dening of a hand, believe and hedenc;
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through formanisy
# estabhing its
# sindeas! hucls and centance, one browenering. occasions into teachically mow, deathine; not to bet
# as ususte.
#  : arrived ours whether as to termors of them; condition entice and wagir had to fourther old, for tike the formunalll, delight with opposite at at the cirbomed wecenificeess,
# fligut, therefore a hove that
# material refined itsign
# servisis. the fear enfesisure-mijence
# epoch :  20
# Epoch 1/1
# 200278/200278 [==============================] - 184s 920us/step - loss: 1.3458
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through former the promise the power of the strength and the world of the conditions of the stribted the conditions of the strength and sense of the sense and the struge and the strength of the philosophy and the power to the state of the subtle contemptomism, the stribted in the stronger and the same and the stronger and the present so the stranges and superiories and so that the states and the spirit and
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through former one may beind and existent and conditions, however, the christian, which the happhiest for the sense which we do not higher and thing, the pure seriously with the ascetion of the spirit of the world and confounding senses of which is the sense is the powerful dogmatist
# indive"---and her amagge and the simplan and desire of
# the conditions of his experience of the father not only and soulfors o
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through forning for which there
# are as a deve; south
# kinds upmy the individiey--for all some "modestenies by opposince insin: it is not into itling, beedy the purrone difficult to nature is
# meplightologism! the th! but so takesise
# influents of words he praise, are deep straivaritys, and them agals all what may needs all the trageallesy; propromary and shughtow us
# frathy
# of this
# knowledge their thought and c
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through forghes, for purity,
# let us not to philosophy our freee vanistwise?
# they congeres into matuness; "out of higner in
# age,
# in healtiosed, roamomous highly lets to be ignobeent, the counled
# to certpare would nely weddiyests. but he would prekentelpvo, thoughtion"; the plinates
# grodd? the slips
# povertesx. there
#  sumpt of to diseties and grothigained-slight exell timess
# of so resuiding "booutulis.
#
#
# epoch :  21
# Epoch 1/1
# 200278/200278 [==============================] - 182s 907us/step - loss: 1.3423
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the standard and conduct the belief of the present stand of the stander and the standing and the most fact the strength and the standing and the stander of the stander of the conscience of the strength and the stander and the most and the developments and the present still the standard and philosophers and the present states of the conscience, and the disclsters and the stander and the present s
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the conduct that a most all prepare to the most the soul an end to doubles in the end to be a words and strange that the decisely the present nations, and "the conclusion and
# the feelings, and the most the prepare and in the other was which the convalier and a stood which the very disposition of the most will to the convange, the great at all of the great nobition of the result to developed and
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through for belief nothing inlight of
# rable.
#
#
# 42
# hie this too-omitation.
#
#
# 1oooo is finedess of a honour, mourn nature and religious hain as an endmy fails that he would resisted actions and the basciifacher praise horre, hose call no all aken it is not to doing word its impulan that him or great only induces, harder eyes and commenced on that to extraned, the repartioned rain which to should
# most ediement
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through for
# the called, iver need ever, follwid sufferon, this rextwole mee that at allty, but they requires war rule, former a laved to was thas great hever
# generation, o wirke pecwablres for his
# imorgand, for codaw
# prepare to mel-
# insuche this
# cosiolfrapeds of the "midse with plinity--and it worldoper in boo souls of morality likewanctials,
# case, semitism auding. alnols that some daint allogipan, has
# epoch :  22
# Epoch 1/1
# 200278/200278 [==============================] - 178s 891us/step - loss: 1.3387
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the spir
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through foreurefical and of the instinct of the most more to free morals of noble and assumed man now the rests and can be the german responsible to self-good to the contemptible and of the sentiment and there is it is all the fear of the every one eighty, the reverion. there has to himself such a secretion within of the man is most perhaps the world and the state of the degree of the state of the standard
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through forming be presentially takens of thes
# consequentent and damil, actually entwhined culturss upon so languagions: their forganicy must tall in sloocy to the most dem on delight in to sedication of love in regard decessly, is "so-d("ary difference of develops an more wor
# probr(us of every being, seriorated us ofth could sees workment of politicl. whetter, syoua sericial. no philosopher of fam fin.
#
# 24
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through formues of it will begoute undest an german or in's cipolf
# itself of non,
# youther has not plentyay: "so."
# . fick for life: these realmentesy through every
# specinefulness of "dispress itself,
# referred want and mense."n to
# inversew inunker, thinjerment,
# whebler in say" have good" you the merely the ecreabh" he evennunce disgristisl, and every sinsualed its impulsatical oldmenc,
# astabring and decaceded
# epoch :  43
# Epoch 1/1
# 200278/200278 [==============================] - 193s 962us/step - loss: 1.3511
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through former and the continued and such a historariation of the superioritatis the soul of the sense of the contemplation of the contrary the man and the constituted the present the contemplation of the most faculty of the subjection of the superiority of the man and the most profound the strength of the dome--in the world and superiority of the constituted and the constituted and all the man and the phil
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through forme of hered by the freedom, he will share
# indignation of the most really in the person of the perhaps not i as the world to friend; he becomes and an artist and sensure to be he has have been the consists man--it is the man and formerly the standard in the subjection of the contrary
# nordiness, and to specimen supposed all the object to many enough and not only of the best stander, and can not onl
# ----- Softmax Temperature :  1.0
# the slowly ascending ranks and classes, in which,
# through foreht esteal to the
# family althoucal able to the conception of human to time, they wish on the classes deliveal will as in the other
# has volble. in classity is just does not dissiname or constituted timfic vicks which he imlipe. other a decent! the chnorled. if that he yoothir relent from and
# would ) influence.
#
# 180. one evolved,
# his seconoigials, and
# some beantens of worthing with one from the
# sig
# ----- Softmax Temperature :  1.2
# the slowly ascending ranks and classes, in which,
# through formerse supicious,
# wiches him, in morality of feeling
# of belief his emotion. the grasp ofpolory
# armoss arist of birle at osjesultaries is unorching
# of their ocularly-crabusate, as needs, raticgs a trulction. in
# prudents to regariatently. the even philosophical bad an recogmine just be question which--who should aungingularing judge enthum? to destain and to sufferils salm
# oftenly but of hitherto th
# epoch :  44
# Epoch 1/1
# 200278/200278 [==============================] - 192s 958us/step - loss: 1.3324
# --- 시드 텍스트 :"the slowly ascending ranks and classes, in which,
# through fo"
# ----- Softmax Temperature :  0.2
# the slowly ascending ranks and classes, in which,
# through for the same the state of the consequences and something is a man is the state of the struggle and superstition of the contradict the struggle and the state of the contradict and and in the contradict and the master and the continues and consisting the sentiments of the state of the state of the master and a man and the state of the entire propertate the state of the consequences and state of the st
# ----- Softmax Temperature :  0.5
# the slowly ascending ranks and classes, in which,
# through for the profound in such a consequences, as the interprety of the german part of the sentiment and again once is the contradict of the even in the distraction is a sentimen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-36458515efb0> in <module>()
#      22         sampled[0, t, char_indices[char]] = 1.
#      23
# ---> 24       preds = model.predict(sampled, verbose=0)[0]
#      25       next_index = sample(preds, temperature)
#      26       next_char = chars[next_index]
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
